# %%
x=1
y=1.2
z= "Hi"
print (x)
print(y)
print (z)
# Out:
# 1
# 1.2
# Hi

# %% [markdown]
# # I created 3 variables, their names are x,y, and z. X is an integer, y is a float, z is a string. i used a print command to print them.

# %%
jar1 = 5
jar2=10
hello="hello"
print (jar1 + jar2 + hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 jar1 = 5
#       2 jar2=10
#       3 hello="hello"
# ----> 4 print (jar1 + jar2 + hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # You can't add string and integers together

# %%
jar1=5
jar2=10
print(jar2)

jar2=jar1
print (jar2)
# Out:
# 10
# 5

# %% [markdown]
# # whatever is on the left of the dequal sign gets set to the value on the right of the equal sign

# %%
name ="John"
age=8
print("My name is", name, "and I am", age, "years old")
# Out:
# My name is John and I am 8 years old

# %%
print ("my name is Tyler")

# %%
tyler = "Tyler"
tyle = "TYLER"
tyl= tyler
print ("My Name Is " + tyler)
print ("my name is " + tyl)
print ("MY NAME IS " + tyle)
# Out:
# My Name Is Tyler
# my name is TYLER
# MY NAME IS Tyler

# %% [markdown]
# # print is a function. I use it by itself and I put what I want to in parentheses. .upper() is a method. I use it on a string. Meaning I create a string, and then call it .upper on the string that I want to convert to upper case.

# %% [markdown]
# you can combine strings and variables with commas

# %%
my_name = "Tyler"

print ("My Name Is " + my_name.upper())
print ("my name is " + my_name.lower())
print ("MY NAME IS " + my_name.title())
# Out:
# My Name Is TYLER
# my name is tyler
# MY NAME IS Tyler

# %%
my_life= "so much fun"
print(my_life.title())
# Out:
# So Much Fun
